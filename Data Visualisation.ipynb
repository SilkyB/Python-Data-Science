# %% [markdown]
# ## Data Visualisation

# %% [markdown]
# `Note` - *This stub file doesn't contain the conceptual questions asked on the platform*

# %% [markdown]
# ### I) Marks Analysis
#
# In the **'Marks.csv'** file, you can find the scores obtained by 200 students in 4 subjects of a standardised test. The different columns - `Score A`, `Score B`, `Score C` and `Score D` indicate the score obtained by a particular student in the respective subjects A, B, C and D.
#
#
#
# Load the dataset to your notebook and answer the following questions

# %%
#Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
df= pd.read_csv('Marks.csv')
df.head()
# Out:
#    Score A  Score B  Score C  Score D
# 0    230.1     37.8     69.2     22.1
# 1     44.5     39.3     45.1     10.4
# 2     17.2     45.9     69.3     12.0
# 3    151.5     41.3     58.5     16.5
# 4    180.8     10.8     58.4     17.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# Score A    200 non-null float64
# Score B    200 non-null float64
# Score C    200 non-null float64
# Score D    200 non-null float64
# dtypes: float64(4)
# memory usage: 6.3 KB

# %% [markdown]
# **Q1)** Load the dataset and plot a histogram for the `Score A` column by keeping the `number of bins to 6`. Which bin range among the following has the highest frequency?
#
# (`Note` - *The bin ranges mentioned in the options are approximate values for the bin ranges that you'll actually get when you plot the histogram*)
#
#     a)0-50
#     b)50-100
#     c)150-200
#     d)200-250

# %%
#Your code here
sns.distplot(df['Score A'],bins = 6)
plt.show()

# %% [markdown]
# **Q2)** Plot a box plot for the column `Score C` and choose the correct option.
#
#     A - The 25th percentile lies between 20 and 40
#     B - The 75th percentile lies between 40 and 60
#     C - The 25th percentile lies between 0 and 20
#     D - Both B and C

# %%
#Your code here
sns.boxplot(data = df['Score C'])

# %% [markdown]
# ### II) Superstore Data
#
# In the `superstore.csv` file, you have the details of orders purchased in an American online retail store. Load the dataset, observe and analyse the different columns and answer the following questions.

# %%
#Load the dataset
df2 = pd.read_csv('superstore.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 9 columns):
# Order ID      9994 non-null object
# Ship Mode     9994 non-null object
# Segment       9994 non-null object
# Region        9994 non-null object
# Product ID    9994 non-null object
# Sales         9994 non-null float64
# Quantity      9994 non-null int64
# Discount      9994 non-null object
# Profit        9994 non-null float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 702.8+ KB

# %%
sns.barplot(data = df2, x = 'Segment', y = 'Sales')
plt.show()
sns.barplot(data = df2, x = 'Segment', y = 'Sales',estimator = np.mean)
plt.show()

# %% [markdown]
# **Q4)** Plot a pie-chart to find the Ship Mode through which most of the orders are being delivered.
#
#      a)Standard Class
#      b)First Class
#      c)Second Class
#      d)Same Day

# %%
#Your code here
df2['Ship Mode'].value_counts().plot.pie()

# %% [markdown]
# **Q5)** Plot a bar chart comparing the average `Discount` across all the `Regions` and report back the `Region` getting the highest average discount
#
# **Note** - You need to clean the `Discount` column first
#
#     a)Central
#     b)South
#     c)West
#     d)East

# %%
df2['Discount'] = df2['Discount'].apply(lambda x: float(x[:-1]))

# %%
df2
# Out:
#             Order ID       Ship Mode      Segment   Region       Product ID  \
# 0     CA-2016-152156    Second Class     Consumer    South  FUR-BO-10001798
# 1     CA-2016-152156    Second Class     Consumer    South  FUR-CH-10000454
# 2     CA-2016-138688    Second Class    Corporate     West  OFF-LA-10000240
# 3     US-2015-108966  Standard Class     Consumer    South  FUR-TA-10000577
# 4     US-2015-108966  Standard Class     Consumer    South  OFF-ST-10000760
# 5     CA-2014-115812  Standard Class     Consumer     West  FUR-FU-10001487
# 6     CA-2014-115812  Standard Class     Consumer     West  OFF-AR-10002833
# 7     CA-2014-115812  Standard Class     Consumer     West  TEC-PH-10002275
# 8     CA-2014-115812  Standard Class     Consumer     West  OFF-BI-10003910
# 9     CA-2014-115812  Standard Class     Consumer     West  OFF-AP-10002892
# 10    CA-2014-115812  Standard Class     Consumer     West  FUR-TA-10001539
# 11    CA-2014-115812  Standard Class     Consumer     West  TEC-PH-10002033
# 12    CA-2017-114412  Standard Class     Consumer    South  OFF-PA-10002365
# 13    CA-2016-161389  Standard Class     Consumer     West  OFF-BI-10003656
# 14    US-2015-118983  Standard Class  Home Office  Central  OFF-AP-10002311
# 15    US-2015-118983  Standard Class  Home Office  Central  OFF-BI-10000756
# 16    CA-2014-105893  Standard Class     Consumer  Central  OFF-ST-10004186
# 17    CA-2014-167164    Second Class     Consumer     West  OFF-ST-10000107
# 18    CA-2014-143336    Second Class     Consumer     West  OFF-AR-10003056
# 19    CA-2014-143336    Second Class     Consumer     West  TEC-PH-10001949
# 20    CA-2014-143336    Second Class     Consumer     West  OFF-BI-10002215
# 21    CA-2016-137330  Standard Class    Corporate  Central  OFF-AR-10000246
# 22    CA-2016-137330  Standard Class    Corporate  Central  OFF-AP-10001492
# 23    US-2017-156909    Second Class     Consumer     East  FUR-CH-10002774
# 24    CA-2015-106320  Standard Class     Consumer     West  FUR-TA-10000577
# 25    CA-2016-121755    Second Class     Consumer     West  OFF-BI-10001634
# 26    CA-2016-121755    Second Class     Consumer     West  TEC-AC-10003027
# 27    US-2015-150630  Standard Class     Consumer     East  FUR-BO-10004834
# 28    US-2015-150630  Standard Class     Consumer     East  OFF-BI-10000474
# 29    US-2015-150630  Standard Class     Consumer     East  FUR-FU-10004848
# ...              ...             ...          ...      ...              ...
# 9964  CA-2016-146374    Second Class    Corporate     East  FUR-FU-10002671
# 9965  CA-2016-146374    Second Class    Corporate     East  OFF-PA-10000349
# 9966  CA-2016-146374    Second Class    Corporate     East  OFF-EN-10004483
# 9967  CA-2017-153871  Standard Class     Consumer     East  OFF-BI-10004209
# 9968  CA-2017-153871  Standard Class     Consumer     East  OFF-BI-10004600
# 9969  CA-2017-153871  Standard Class     Consumer     East  OFF-AP-10003622
# 9970  CA-2015-103772  Standard Class  Home Office    South  OFF-BI-10002867
# 9971  CA-2015-103772  Standard Class  Home Office    South  OFF-AR-10000538
# 9972  CA-2016-130225  Standard Class     Consumer  Central  OFF-EN-10000056
# 9973  US-2016-103674  Standard Class  Home Office     West  TEC-PH-10004080
# 9974  US-2016-103674  Standard Class  Home Office     West  OFF-AR-10004752
# 9975  US-2016-103674  Standard Class  Home Office     West  OFF-PA-10000743
# 9976  US-2016-103674  Standard Class  Home Office     West  TEC-PH-10002496
# 9977  US-2016-103674  Standard Class  Home Office     West  OFF-FA-10003467
# 9978  US-2016-103674  Standard Class  Home Office     West  OFF-BI-10003727
# 9979  US-2016-103674  Standard Class  Home Office     West  OFF-BI-10002026
# 9980  US-2015-151435    Second Class     Consumer    South  FUR-TA-10001039
# 9981  CA-2017-163566     First Class     Consumer     East  OFF-LA-10004484
# 9982  US-2016-157728  Standard Class     Consumer  Central  OFF-PA-10002195
# 9983  US-2016-157728  Standard Class     Consumer  Central  TEC-PH-10001305
# 9984  CA-2015-100251  Standard Class     Consumer     East  OFF-LA-10003766
# 9985  CA-2015-100251  Standard Class     Consumer     East  OFF-SU-10000898
# 9986  CA-2016-125794  Standard Class     Consumer     West  TEC-AC-10003399
# 9987  CA-2017-163629  Standard Class    Corporate    South  TEC-AC-10001539
# 9988  CA-2017-163629  Standard Class    Corporate    South  TEC-PH-10004006
# 9989  CA-2014-110422    Second Class     Consumer    South  FUR-FU-10001889
# 9990  CA-2017-121258  Standard Class     Consumer     West  FUR-FU-10000747
# 9991  CA-2017-121258  Standard Class     Consumer     West  TEC-PH-10003645
# 9992  CA-2017-121258  Standard Class     Consumer     West  OFF-PA-10004041
# 9993  CA-2017-119914    Second Class     Consumer     West  OFF-AP-10002684
#
#           Sales  Quantity  Discount     Profit
# 0      261.9600         2      0.00    41.9136
# 1      731.9400         3      0.00   219.5820
# 2       14.6200         2      0.00     6.8714
# 3      957.5775         5      0.45  -383.0310
# 4       22.3680         2      0.20     2.5164
# 5       48.8600         7      0.00    14.1694
# 6        7.2800         4      0.00     1.9656
# 7      907.1520         6      0.20    90.7152
# 8       18.5040         3      0.20     5.7825
# 9      114.9000         5      0.00    34.4700
# 10    1706.1840         9      0.20    85.3092
# 11     911.4240         4      0.20    68.3568
# 12      15.5520         3      0.20     5.4432
# 13     407.9760         3      0.20   132.5922
# 14      68.8100         5      0.80  -123.8580
# 15       2.5440         3      0.80    -3.8160
# 16     665.8800         6      0.00    13.3176
# 17      55.5000         2      0.00     9.9900
# 18       8.5600         2      0.00     2.4824
# 19     213.4800         3      0.20    16.0110
# 20      22.7200         4      0.20     7.3840
# 21      19.4600         7      0.00     5.0596
# 22      60.3400         7      0.00    15.6884
# 23      71.3720         2      0.30    -1.0196
# 24    1044.6300         3      0.00   240.2649
# 25      11.6480         2      0.20     4.2224
# 26      90.5700         3      0.00    11.7741
# 27    3083.4300         7      0.50 -1665.0522
# 28       9.6180         2      0.70    -7.0532
# 29     124.2000         3      0.20    15.5250
# ...         ...       ...       ...        ...
# 9964    13.4000         1      0.00     6.4320
# 9965     4.9800         1      0.00     2.3406
# 9966   109.6900         7      0.00    51.5543
# 9967    40.2000         5      0.00    18.0900
# 9968   735.9800         2      0.00   331.1910
# 9969    22.7500         7      0.00     6.5975
# 9970   119.5600         2      0.00    54.9976
# 9971   140.7500         5      0.00    42.2250
# 9972    99.5680         2      0.20    33.6042
# 9973   271.9600         5      0.20    27.1960
# 9974    18.6900         7      0.00     5.2332
# 9975    13.3600         2      0.00     6.4128
# 9976   249.5840         2      0.20    31.1980
# 9977    13.8600         7      0.00     0.0000
# 9978    13.3760         4      0.20     4.6816
# 9979   437.4720        14      0.20   153.1152
# 9980    85.9800         1      0.00    22.3548
# 9981    16.5200         5      0.20     5.3690
# 9982    35.5600         7      0.00    16.7132
# 9983    97.9800         2      0.00    27.4344
# 9984    31.5000        10      0.00    15.1200
# 9985    55.6000         4      0.00    16.1240
# 9986    36.2400         1      0.00    15.2208
# 9987    79.9900         1      0.00    28.7964
# 9988   206.1000         5      0.00    55.6470
# 9989    25.2480         3      0.20     4.1028
# 9990    91.9600         2      0.00    15.6332
# 9991   258.5760         2      0.20    19.3932
# 9992    29.6000         4      0.00    13.3200
# 9993   243.1600         2      0.00    72.9480
#
# [9994 rows x 9 columns]

# %%
#Your code here
sns.barplot(data = df2, x= 'Region', y = 'Discount', estimator = np.mean)
